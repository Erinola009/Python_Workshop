# %% [markdown]
# ### FILE HANDLING
# Data scientist work with different file types ranging from, txt, csv, json, excell,
# xml among others. those files helps to store data which are usful for darta anlsys and machine learning
# operations, they can be handled with the python programming language.

# %%
# Reading a text file
file_name = "sample_file.txt"

# %%
# Using the python open statement to READ text file
file = open(filename, mode="r")

# %%
file.readline()
# Out:
# 'This is our data science course\n'

# %%
file.readline()
# Out:
# 'We are learning data science skills'

# %%
file.close()

# %% [markdown]
# ### CONTEXT MANAGER
# The context manager helps to handle the opening and closing of files in Python

# %%
with open("class_people.csv", "r") as file:
    print(file.read())
# Out:
#  name, age, gender
# Osato, 30, Female
#  This is end of the file
#  This is end of the file

# %%
#filewc = r"C:\Users\MAC\Desktop\Python_Workshop\world_cup_2018_matches.csv"
#filewc.readline()
# Out:
# ------------------------------------------------------------------
# AttributeError                   Traceback (most recent call last)
# Cell In[83], line 2
#       1 filewc = r"C:\Users\MAC\Desktop\Python_Workshop\world_cup_2018_matches.csv"
# ----> 2 filewc.readline()
#
# AttributeError: 'str' object has no attribute 'readline'

# %% [markdown]
# ### USING THE PYTHON CSV MODULE
# Just like we have other built in python, we have the csv module built in python. we can just import csv access its capabilities

# %%
import csv

# %%
with open(r"C:\Users\MAC\Desktop\Python_Workshop\world_cup_2018_matches.csv", "r") as f:
    for i in csv.reader(f):
        print(i[0])
# Out:
# Match ID
# 497410
# 497411
# 497412
# 497413
# 497414
# 497415
# 497416
# 497417
# 497418
# 497419
# 497422
# 497423
# 497424
# 497426
# 497427
# 497428
# 497421
# 497420
# 497429
# 497425
# 497430
# 497431
# 497433
# 497434
# 497435
# 497438
# 497439
# 497432
# 497437
# 497436
# 497447
# 497442
# 497443
# 497444
# 497445
# 497446
# 497441
# 497440
# 497448
# 497449
# 497459
# 497450
# 497453
# 497454
# 497455
# 497457
# 497458
# 497452
# 497451
# 497456
# 497467
# 497461
# 497462
# 497463
# 497464
# 497468
# 497469
# 497465
# 497466
# 497460
# 497475
# 497470
# 497472
# 497474
# 497477
# 497478
# 497479
# 497476
# 497471
# 497473
# 497488
# 497481
# 497482
# 497484
# 497485
# 497487
# 497483
# 497480
# 497489
# 497486
# 497497
# 497491
# 497492
# 497493
# 497498
# 497496
# 497494
# 497495
# 497499
# 497490
# 497500
# 497501
# 497502
# 497503
# 497504
# 497505
# 497506
# 497507
# 497508
# 497509
# 497510
# 497511
# 497512
# 497513
# 497514
# 497515
# 497516
# 497517
# 497518
# ...

# %%
import pandas as pd

# Load the data from the CSV file
file_path = r"C:\Users\MAC\Desktop\Python_Workshop\world_cup_2018_matches.csv"
data = pd.read_csv(file_path)

# Display the DataFrame
data
# Out:
#      Match ID                   Home Team                   Away Team  \
# 0      497410        Manchester United FC                   Fulham FC
# 1      497411             Ipswich Town FC                Liverpool FC
# 2      497412                  Arsenal FC  Wolverhampton Wanderers FC
# 3      497413                  Everton FC   Brighton & Hove Albion FC
# 4      497414         Newcastle United FC              Southampton FC
# ..        ...                         ...                         ...
# 375    497785         Newcastle United FC                  Everton FC
# 376    497786        Nottingham Forest FC                  Chelsea FC
# 377    497787              Southampton FC                  Arsenal FC
# 378    497788        Tottenham Hotspur FC   Brighton & Hove Albion FC
# 379    497789  Wolverhampton Wanderers FC                Brentford FC
#
#      Home Score  Away Score            Match Date
# 0           1.0         0.0  2024-08-16T19:00:00Z
# ...

# %%
data.dtypes
# Out:
# Match ID        int64
# Home Team      object
# Away Team      object
# Home Score    float64
# Away Score    float64
# Match Date     object
# dtype: object

# %% [markdown]
# ### WORKING WITH JSON FILES
# Json stands for Javascript object notation, Python has a json built in module to handle json files

# %%
import json
# There two important method in json(1. load, 2.dump)

# %%
# Loading files with numpy
# There are functions / method to load for laoding dataset in numpy:
# genfromtxt
# Loadfromtxt
import numpy as np

# %%
loan_amount = np.genfromtxt(r"C:\Users\MAC\Loan_prediction_dataset.csv", filling_values= 0, dtype= "int", delimiter=",", usecols=8)

# %%
loan_amount
# Out:
# array([  0,   0, 128,  66, 120, 141, 267,  95, 158, 168, 349,  70, 109,
#        200, 114,  17, 125, 100,  76, 133, 115, 104, 315, 116, 112, 151,
#        191, 122, 110,  35, 120, 201,  74, 106, 114, 320,   0, 100, 144,
#        184, 110,  80,  47,  75, 134,  96,  88,  44, 144, 120, 144, 100,
#        120, 112, 134, 286,  97,  96, 135, 180, 144, 120,  99, 165,   0,
#        116, 258, 126, 312, 125, 136, 172,  97,  81,  95, 187, 113, 176,
#        110, 180, 130, 111,   0, 167, 265,  50, 136,  99, 104, 210, 175,
#        131, 188,  81, 122,  25,   0, 137,  50, 115, 131, 133, 151,   0,
#          0, 160, 100, 225, 120, 216,  94, 136, 139, 152,   0, 118, 185,
#        154,  85, 175, 259, 180,  44, 137,  81, 194,  93, 370,   0, 160,
#        182, 650,  74,  70,  25, 102, 290,  84,  88, 242, 129, 185, 168,
#        175, 122, 187, 100,  70,  30, 225, 125, 118, 152, 244, 113,  50,
#        600, 160, 187, 120, 255,  98, 275, 121, 158,  75, 182, 112, 129,
# ...

# %%
loan_max = np.max(loan_amount)
print(f"Maximum loan_amount: {loan_max}")
# Out:
# Maximum loan_amount: 81000

# %%
loan_max = np.mean(loan_amount)
print(f"Mean of loan_amount: {loan_max}")
# Out:
# Mean of loan_amount: 140.93658536585366
