# %% [markdown]
# ### OLALEKAN ELEBUTE
# *** PYTHON - data visualization with python

# %% [markdown]
# Instructions
#
#     Load the dataset into a data frame using Python.
#     Clean the data as needed.
#     Plot a line chart to show the average temperature fluctuations in Tunisia and Cameroon. Interpret the results.
#     Zoom in to only include data between 1980 and 2005, try to customize the axes labels.
#     Create Histograms to show temperature distribution in Senegal between [1980,2000] and [2000,2023] (in the same figure). Describe the obtained results.
#     Select the best chart to show the Average temperature per country.
#     Make your own questions about the dataset and try to answer them using the appropriate visuals.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
url = (r"C:\Users\MAC\Africa_climate_change.csv")
datafile = pd.read_csv(r"C:\Users\MAC\Africa_climate_change.csv")

# %%
datafile.head()
# Out:
#               DATE  PRCP  TAVG  TMAX  TMIN   COUNTRY
# 0  19800101 000000   NaN  54.0  61.0  43.0   Tunisia
# 1  19800101 000000   NaN  49.0  55.0  41.0   Tunisia
# 2  19800101 000000   0.0  72.0  86.0  59.0  Cameroon
# 3  19800101 000000   NaN  50.0  55.0  43.0   Tunisia
# 4  19800101 000000   NaN  75.0  91.0   NaN  Cameroon

# %%
(datafile.isnull().sum())
# Out:
# DATE            0
# PRCP       287240
# TAVG         6376
# TMAX       100914
# TMIN       132058
# COUNTRY         0
# dtype: int64

# %%
datafile.dropna(inplace=True)
datafile['DATE'] = pd.to_datetime(data['DATE'])

# %%
(datafile.dtypes)
# Out:
# DATE       datetime64[ns]
# PRCP              float64
# TAVG              float64
# TMAX              float64
# TMIN              float64
# COUNTRY            object
# dtype: object

# %%
import matplotlib.pyplot as plt

# %%
(datafile.isnull().sum())
# Out:
# DATE       0
# PRCP       0
# TAVG       0
# TMAX       0
# TMIN       0
# COUNTRY    0
# dtype: int64

# %%
tunisia_data = data[data['COUNTRY'] == 'Tunisia']
cameroon_data = data[data['COUNTRY'] == 'Cameroon']

# %%
plt.figure(figsize=(14, 7))
plt.plot(tunisia_data['DATE'], tunisia_data['TAVG'], label='Tunisia', color='blue')
plt.plot(cameroon_data['DATE'], cameroon_data['TAVG'], label='Cameroon', color='orange')

# %%
plt.title('Average Temperature Fluctuations: Tunisia vs Cameroon (1980-2023)')
plt.xlabel('Year')
plt.ylabel('Average Temperature (°C)')
plt.legend()
plt.grid()
plt.show()
# Out:
# C:\Users\MAC\AppData\Local\Temp\ipykernel_12188\3750315126.py:4: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
(datafile.isnull().sum())
# Out:
# DATE       0
# PRCP       0
# TAVG       0
# TMAX       0
# TMIN       0
# COUNTRY    0
# dtype: int64

# %%
# Filter data between 1980 and 2005
tunisia_data_1980_2005 = tunisia_data[(tunisia_data['DATE'] >= '1980-01-01') & (tunisia_data['DATE'] <= '2005-12-31')]
cameroon_data_1980_2005 = cameroon_data[(cameroon_data['DATE'] >= '1980-01-01') & (cameroon_data['DATE'] <= '2005-12-31')]

# %%
plt.figure(figsize=(14, 7))
plt.plot(tunisia_data_1980_2005['DATE'], tunisia_data_1980_2005['TAVG'], label='Tunisia', color='blue')
plt.plot(cameroon_data_1980_2005['DATE'], cameroon_data_1980_2005['TAVG'], label='Cameroon', color='orange')

# %%
plt.title('Average Temperature (1980-2005): Tunisia vs Cameroon')
plt.xlabel('Year')
plt.ylabel('Average Temperature (°C)')
plt.xticks(rotation=45)
plt.legend()
plt.grid()
plt.show()
# Out:
# C:\Users\MAC\AppData\Local\Temp\ipykernel_12188\1037753621.py:5: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
# Filter for Senegal data
senegal_data = data[data['COUNTRY'] == 'Senegal']

# %%
senegal_data_1980_2000 = senegal_data[(senegal_data['DATE'] >= '1980-01-01') & (senegal_data['DATE'] <= '2000-12-31')]
senegal_data_2000_2023 = senegal_data[(senegal_data['DATE'] > '2000-12-31') & (senegal_data['DATE'] <= '2023-12-31')]

# %%
plt.figure(figsize=(12, 6))

# %%
plt.subplot(1, 2, 1)
plt.hist(senegal_data_1980_2000['TAVG'], bins=20, color='green', alpha=0.7)
plt.title('Temperature Distribution in Senegal (1980-2000)')
plt.xlabel('Average Temperature (°C)')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.subplot(1, 2, 2)
plt.hist(senegal_data_2000_2023['TAVG'], bins=20, color='red', alpha=0.7)
plt.title('Temperature Distribution in Senegal (2000-2023)')
plt.xlabel('Average Temperature (°C)')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()
