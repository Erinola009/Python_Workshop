# %% [markdown]
# # OLALEKAN P ELEBUTE #
# ### Data pre-processing checkpoint

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Instructions
#
#     Load the dataset, display the ten first lines, store the results in a variable called 'client_0_bills'.
#     What is the data type of the 'client_0_bills' variable ?
#     Display the general information of the dataset and try to answer the following questions :
#     How many rows and columns do we have in this dataset ?
#     How many categorical features are present in the dataset ?
#     How much memory space does the dataset consume ?
#     Inspect the dataset for potential missing values.
#     Select your strategy to handle missing values, and tell us why you had made that choice.
#     Run a descriptive analysis on numeric features (columns).
#     Select the bills records for the client with an id ='train_Client_0', using 2 methods.
#     Transform the 'counter_type' feature to a numeric variable using the encoder of your choice.
#     Delete the 'counter_statue' feature from the Dataframe

# %%
Data_file = pd.read_csv(r"C:\Users\MAC\Desktop\Python_Workshop\STEG_BILLING_HISTORY.csv")
Data_file.head()
# Out:
# C:\Users\MAC\AppData\Local\Temp\ipykernel_8812\3646758532.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   Data_file = pd.read_csv(r"C:\Users\MAC\Desktop\Python_Workshop\STEG_BILLING_HISTORY.csv")
#         client_id invoice_date  tarif_type  counter_number counter_statue  \
# 0  train_Client_0   2014-03-24          11       1335667.0              0
# 1  train_Client_0   2013-03-29          11       1335667.0              0
# 2  train_Client_0   2015-03-23          11       1335667.0              0
# 3  train_Client_0   2015-07-13          11       1335667.0              0
# 4  train_Client_0   2016-11-17          11       1335667.0              0
#
#    counter_code  reading_remarque  counter_coefficient  consommation_level_1  \
# 0           203               8.0                    1                    82
# 1           203               6.0                    1                  1200
# 2           203               8.0                    1                   123
# 3           207               8.0                    1                   102
# 4           207               9.0                    1                   572
#
#    consommation_level_2  consommation_level_3  consommation_level_4  \
# 0                     0                     0                     0
# 1                   184                     0                     0
# 2                     0                     0                     0
# 3                     0                     0                     0
# 4                     0                     0                     0
#
#    old_index  new_index  months_number counter_type
# 0      14302      14384              4         ELEC
# 1      12294      13678              4         ELEC
# 2      14624      14747              4         ELEC
# 3      14747      14849              4         ELEC
# 4      15066      15638             12         ELEC

# %%
Data_file.months_number.nunique()
# Out:
# 1370

# %%
df = pd.read_csv(r"C:\Users\MAC\Desktop\Python_Workshop\STEG_BILLING_HISTORY.csv")
# Out:
# C:\Users\MAC\AppData\Local\Temp\ipykernel_8812\2818899610.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"C:\Users\MAC\Desktop\Python_Workshop\STEG_BILLING_HISTORY.csv")

# %%
client_0_bills = df.head(5)
print(client_0_bills)
# Out:
#         client_id invoice_date  tarif_type  counter_number counter_statue  \
# 0  train_Client_0   2014-03-24          11       1335667.0              0
# 1  train_Client_0   2013-03-29          11       1335667.0              0
# 2  train_Client_0   2015-03-23          11       1335667.0              0
# 3  train_Client_0   2015-07-13          11       1335667.0              0
# 4  train_Client_0   2016-11-17          11       1335667.0              0
#
#    counter_code  reading_remarque  counter_coefficient  consommation_level_1  \
# 0           203               8.0                    1                    82
# 1           203               6.0                    1                  1200
# 2           203               8.0                    1                   123
# 3           207               8.0                    1                   102
# 4           207               9.0                    1                   572
#
#    consommation_level_2  consommation_level_3  consommation_level_4  \
# 0                     0                     0                     0
# 1                   184                     0                     0
# 2                     0                     0                     0
# 3                     0                     0                     0
# 4                     0                     0                     0
#
#    old_index  new_index  months_number counter_type
# 0      14302      14384              4         ELEC
# 1      12294      13678              4         ELEC
# 2      14624      14747              4         ELEC
# 3      14747      14849              4         ELEC
# 4      15066      15638             12         ELEC

# %%
client_0_bills.dtypes
# Out:
# client_id                object
# invoice_date             object
# tarif_type                int64
# counter_number          float64
# counter_statue           object
# counter_code              int64
# reading_remarque        float64
# counter_coefficient       int64
# consommation_level_1      int64
# consommation_level_2      int64
# consommation_level_3      int64
# consommation_level_4      int64
# old_index                 int64
# new_index                 int64
# months_number             int64
# counter_type             object
# dtype: object

# %%
Data_file.describe()
# Out:
#          tarif_type  counter_number  counter_code  reading_remarque  \
# count  4.476749e+06    4.476701e+06  4.476749e+06      4.472218e+06
# mean   2.012804e+01    1.230595e+11  1.724884e+02      7.321713e+00
# std    1.347256e+01    1.657276e+12  1.338871e+02      1.571859e+00
# min    8.000000e+00    0.000000e+00  0.000000e+00      5.000000e+00
# 25%    1.100000e+01    1.211080e+05  5.000000e+00      6.000000e+00
# 50%    1.100000e+01    4.945610e+05  2.030000e+02      8.000000e+00
# 75%    4.000000e+01    1.115161e+06  2.070000e+02      9.000000e+00
# max    4.500000e+01    2.798115e+13  6.000000e+02      4.130000e+02
#
#        counter_coefficient  consommation_level_1  consommation_level_2  \
# count         4.476749e+06          4.476749e+06          4.476749e+06
# mean          1.003040e+00          4.109795e+02          1.093225e+02
# std           3.083466e-01          7.573080e+02          1.220123e+03
# min           0.000000e+00          0.000000e+00          0.000000e+00
# 25%           1.000000e+00          7.900000e+01          0.000000e+00
# 50%           1.000000e+00          2.740000e+02          0.000000e+00
# 75%           1.000000e+00          6.000000e+02          0.000000e+00
# max           5.000000e+01          9.999100e+05          9.990730e+05
#
#        consommation_level_3  consommation_level_4     old_index     new_index  \
# count          4.476749e+06          4.476749e+06  4.476749e+06  4.476749e+06
# mean           2.030620e+01          5.292588e+01  1.776700e+04  1.834970e+04
# std            1.574239e+02          8.754725e+02  4.036693e+04  4.095321e+04
# min            0.000000e+00          0.000000e+00  0.000000e+00  0.000000e+00
# 25%            0.000000e+00          0.000000e+00  1.791000e+03  2.056000e+03
# 50%            0.000000e+00          0.000000e+00  7.690000e+03  8.192000e+03
# 75%            0.000000e+00          0.000000e+00  2.166000e+04  2.234300e+04
# max            6.449200e+04          5.479460e+05  2.800280e+06  2.870972e+06
#
#        months_number
# count   4.476749e+06
# mean    4.483095e+01
# std     3.128335e+03
# min     0.000000e+00
# 25%     4.000000e+00
# 50%     4.000000e+00
# 75%     4.000000e+00
# max     6.366240e+05

# %%
df_info = df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4476749 entries, 0 to 4476748
# Data columns (total 16 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   client_id             object
#  1   invoice_date          object
#  2   tarif_type            int64
#  3   counter_number        float64
#  4   counter_statue        object
#  5   counter_code          int64
#  6   reading_remarque      float64
#  7   counter_coefficient   int64
#  8   consommation_level_1  int64
#  9   consommation_level_2  int64
#  10  consommation_level_3  int64
#  11  consommation_level_4  int64
#  12  old_index             int64
#  13  new_index             int64
#  14  months_number         int64
#  15  counter_type          object
# dtypes: float64(2), int64(10), object(4)
# memory usage: 546.5+ MB

# %%
num_rows, num_columns = df.shape
print(f"Number of rows: {num_rows}, Number of columns: {num_columns}")
# Out:
# Number of rows: 4476749, Number of columns: 16

# %%
# Count categorical features
categorical_features = df.select_dtypes(include=['object']).columns
num_categorical_features = len(categorical_features)
print(f"Number of categorical features: {num_categorical_features}")
# Out:
# Number of categorical features: 4

# %%
memory_usage = df.memory_usage(deep=True).sum()
(f"Memory usage: {memory_usage} bytes")
# Out:
# 'Memory usage: 1012554257 bytes'

# %%
missing_values = df.isnull().sum()
print(missing_values[missing_values > 0])
# Out:
# Series([], dtype: int64)

# %%
# Example strategy: Fill missing values with the mean for numeric columns
for column in df.select_dtypes(include=['float64', 'int64']).columns:
    df[column].fillna(df[column].mean(), inplace=True)
# Out:
# C:\Users\MAC\AppData\Local\Temp\ipykernel_8812\148610530.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[column].fillna(df[column].mean(), inplace=True)

# %%
# Descriptive analysis
descriptive_stats = df.describe()
descriptive_stats.head()
# Out:
#          tarif_type  counter_number  counter_code  reading_remarque  \
# count  4.476749e+06    4.476749e+06  4.476749e+06      4.476749e+06
# mean   2.012804e+01    1.230595e+11  1.724884e+02      7.321713e+00
# std    1.347256e+01    1.657267e+12  1.338871e+02      1.571064e+00
# min    8.000000e+00    0.000000e+00  0.000000e+00      5.000000e+00
# 25%    1.100000e+01    1.211080e+05  5.000000e+00      6.000000e+00
#
#        counter_coefficient  consommation_level_1  consommation_level_2  \
# count         4.476749e+06          4.476749e+06          4.476749e+06
# mean          1.003040e+00          4.109795e+02          1.093225e+02
# std           3.083466e-01          7.573080e+02          1.220123e+03
# min           0.000000e+00          0.000000e+00          0.000000e+00
# 25%           1.000000e+00          7.900000e+01          0.000000e+00
#
#        consommation_level_3  consommation_level_4     old_index     new_index  \
# count          4.476749e+06          4.476749e+06  4.476749e+06  4.476749e+06
# mean           2.030620e+01          5.292588e+01  1.776700e+04  1.834970e+04
# std            1.574239e+02          8.754725e+02  4.036693e+04  4.095321e+04
# min            0.000000e+00          0.000000e+00  0.000000e+00  0.000000e+00
# 25%            0.000000e+00          0.000000e+00  1.791000e+03  2.056000e+03
#
#        months_number  counter_type
# count   4.476749e+06  4.476749e+06
# mean    4.483095e+01  3.121334e-01
# std     3.128335e+03  4.633640e-01
# min     0.000000e+00  0.000000e+00
# 25%     4.000000e+00  0.000000e+00

# %%
# Method 1: Using boolean indexing
client_0_records_1 = df[df['client_id'] == 'train_Client_0']

# Method 2: Using query method
client_0_records_2 = df.query("client_id == 'train_Client_0'")

# %%
client_0_records_1.head()
# Out:
#         client_id invoice_date  tarif_type  counter_number counter_statue  \
# 0  train_Client_0   2014-03-24          11       1335667.0              0
# 1  train_Client_0   2013-03-29          11       1335667.0              0
# 2  train_Client_0   2015-03-23          11       1335667.0              0
# 3  train_Client_0   2015-07-13          11       1335667.0              0
# 4  train_Client_0   2016-11-17          11       1335667.0              0
#
#    counter_code  reading_remarque  counter_coefficient  consommation_level_1  \
# 0           203               8.0                    1                    82
# 1           203               6.0                    1                  1200
# 2           203               8.0                    1                   123
# 3           207               8.0                    1                   102
# 4           207               9.0                    1                   572
#
#    consommation_level_2  consommation_level_3  consommation_level_4  \
# 0                     0                     0                     0
# 1                   184                     0                     0
# 2                     0                     0                     0
# 3                     0                     0                     0
# 4                     0                     0                     0
#
#    old_index  new_index  months_number counter_type
# 0      14302      14384              4         ELEC
# 1      12294      13678              4         ELEC
# 2      14624      14747              4         ELEC
# 3      14747      14849              4         ELEC
# 4      15066      15638             12         ELEC

# %%
client_0_records_2.head()
# Out:
#         client_id invoice_date  tarif_type  counter_number  counter_code  \
# 0  train_Client_0   2014-03-24          11       1335667.0           203
# 1  train_Client_0   2013-03-29          11       1335667.0           203
# 2  train_Client_0   2015-03-23          11       1335667.0           203
# 3  train_Client_0   2015-07-13          11       1335667.0           207
# 4  train_Client_0   2016-11-17          11       1335667.0           207
#
#    reading_remarque  counter_coefficient  consommation_level_1  \
# 0               8.0                    1                    82
# 1               6.0                    1                  1200
# 2               8.0                    1                   123
# 3               8.0                    1                   102
# 4               9.0                    1                   572
#
#    consommation_level_2  consommation_level_3  consommation_level_4  \
# 0                     0                     0                     0
# 1                   184                     0                     0
# 2                     0                     0                     0
# 3                     0                     0                     0
# 4                     0                     0                     0
#
#    old_index  new_index  months_number  counter_type
# 0      14302      14384              4             0
# 1      12294      13678              4             0
# 2      14624      14747              4             0
# 3      14747      14849              4             0
# 4      15066      15638             12             0

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['counter_type'] = le.fit_transform(df['counter_type'])

# %%
# Drop the 'counter_statue' feature
df.drop(columns=['counter_statue'], inplace=True)
